# %%
# !pip install azure-storage-blob # Microoft Azure
# !pip install pyarrow
# !pip install psycopg2 sqlalchemy
# Out:
# Collecting azure-storage-blob
#   Downloading azure_storage_blob-12.19.1-py3-none-any.whl (394 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.5/394.5 kB 5.2 MB/s eta 0:00:00
# Collecting azure-core<2.0.0,>=1.28.0 (from azure-storage-blob)
#   Downloading azure_core-1.30.1-py3-none-any.whl (193 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.4/193.4 kB 10.8 MB/s eta 0:00:00
# Requirement already satisfied: cryptography>=2.1.4 in /usr/local/lib/python3.10/dist-packages (from azure-storage-blob) (42.0.5)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from azure-storage-blob) (4.11.0)
# Collecting isodate>=0.6.1 (from azure-storage-blob)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from azure-core<2.0.0,>=1.28.0->azure-storage-blob) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from azure-core<2.0.0,>=1.28.0->azure-storage-blob) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=2.1.4->azure-storage-blob) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (2024.2.2)
# Installing collected packages: isodate, azure-core, azure-storage-blob
# Successfully installed azure-core-1.30.1 azure-storage-blob-12.19.1 isodate-0.6.1
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.10/dist-packages (14.0.2)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.10/dist-packages (from pyarrow) (1.25.2)
# Requirement already satisfied: psycopg2 in /usr/local/lib/python3.10/dist-packages (2.9.9)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.10/dist-packages (2.0.29)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy) (3.0.3)

# %%
import pandas as pd
import numpy as np
import json
import requests
from io import StringIO
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient
from math import ceil
import datetime
import calendar
from sqlalchemy import create_engine

# %%
# Azure Functions
def azure_upload_blob(connect_str, container_name, blob_name, data):
    blob_service_client = BlobServiceClient.from_connection_string(connect_str)
    blob_client = blob_service_client.get_blob_client(container=container_name, blob=blob_name)
    blob_client.upload_blob(data, overwrite=True)
    print(f"Uploaded to Azure Blob: {blob_name}")

def azure_download_blob(connect_str, container_name, blob_name):
    blob_service_client = BlobServiceClient.from_connection_string(connect_str)
    blob_client = blob_service_client.get_blob_client(container=container_name, blob=blob_name)
    download_stream = blob_client.download_blob()
    return download_stream.readall()

# %%
# Specify the path to JSON configuration file
config_file_path = 'config.json'

# Load the JSON configuration file
with open(config_file_path, 'r') as config_file:
    config = json.load(config_file)

# Print the configuration
#Connection_STRING = config["connectionString"]

CONNECTION_STRING_AZURE_STORAGE = config["connectionString"]
CONTAINER_AZURE = 'propertyassessment'

# Initialize the BlobServiceClient
blob_service_client = BlobServiceClient.from_connection_string(CONNECTION_STRING_AZURE_STORAGE)

# Get the container client
container_client = blob_service_client.get_container_client(CONTAINER_AZURE)


property_assessment_df = pd.DataFrame()

# List all blobs in the specified container
blob_list = container_client.list_blobs()
for blob in blob_list:
    print(blob.name)
    blob_client = container_client.get_blob_client(blob=blob.name)
    blob_data = blob_client.download_blob()
    blob_content = blob_data.readall().decode('utf-8')
    df = pd.read_csv(StringIO(blob_content))
    # Display the head of the DataFrame
    print(df.shape)
    property_assessment_df = df.copy()
# Out:
# fy2024-property-assessment-data_1_5_2024.csv
# <ipython-input-4-721f973491e2>:30: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(StringIO(blob_content))
# (182242, 65)

# %%
# check the columns name
property_assessment_df.columns
# Out:
# Index(['PID', 'CM_ID', 'GIS_ID', 'ST_NUM', 'ST_NAME', 'UNIT_NUM', 'CITY',
#        'ZIP_CODE', 'BLDG_SEQ', 'NUM_BLDGS', 'LUC', 'LU', 'LU_DESC',
#        'BLDG_TYPE', 'OWN_OCC', 'OWNER', 'MAIL_ADDRESSEE',
#        'MAIL_STREET_ADDRESS', 'MAIL_CITY', 'MAIL_STATE', 'MAIL_ZIP_CODE',
#        'RES_FLOOR', 'CD_FLOOR', 'RES_UNITS', 'COM_UNITS', 'RC_UNITS',
#        'LAND_SF', 'GROSS_AREA', 'LIVING_AREA', 'LAND_VALUE', 'BLDG_VALUE',
#        'SFYI_VALUE', 'TOTAL_VALUE', ' GROSS_TAX ', 'YR_BUILT', 'YR_REMODEL',
#        'STRUCTURE_CLASS', 'ROOF_STRUCTURE', 'ROOF_COVER', 'INT_WALL',
#        'EXT_FNISHED', 'INT_COND', 'EXT_COND', 'OVERALL_COND', 'BED_RMS',
#        'FULL_BTH', 'HLF_BTH', 'KITCHENS', 'TT_RMS', 'BDRM_COND',
#        'BTHRM_STYLE1', 'BTHRM_STYLE2', 'BTHRM_STYLE3', 'KITCHEN_TYPE',
#        'KITCHEN_STYLE1', 'KITCHEN_STYLE2', 'KITCHEN_STYLE3', 'HEAT_TYPE',
#        'HEAT_SYSTEM', 'AC_TYPE', 'FIREPLACES', 'ORIENTATION', 'NUM_PARKING',
#        'PROP_VIEW', 'CORNER_UNIT'],
#       dtype='object')

# %%
property_assessment_df.head()
# Out:
#          PID  CM_ID     GIS_ID  ST_NUM       ST_NAME UNIT_NUM         CITY  \
# 0  100001000    NaN  100001000   104.0     PUTNAM ST      NaN  EAST BOSTON
# 1  100002000    NaN  100002000   197.0  Lexington ST      NaN  EAST BOSTON
# 2  100003000    NaN  100003000   199.0  Lexington ST      NaN  EAST BOSTON
# 3  100004000    NaN  100004000   201.0  Lexington ST      NaN  EAST BOSTON
# 4  100005000    NaN  100005000   203.0  Lexington ST      NaN  EAST BOSTON
#
#    ZIP_CODE  BLDG_SEQ  NUM_BLDGS  ...     KITCHEN_STYLE2   KITCHEN_STYLE3  \
# 0    2128.0         1          1  ...    S - Semi-Modern  S - Semi-Modern
# 1    2128.0         1          1  ...         M - Modern       M - Modern
# 2    2128.0         1          1  ...    S - Semi-Modern  S - Semi-Modern
# 3    2128.0         1          1  ...    S - Semi-Modern  S - Semi-Modern
# 4    2128.0         1          1  ...  N - No Remodeling              NaN
#
#             HEAT_TYPE HEAT_SYSTEM         AC_TYPE FIREPLACES ORIENTATION  \
# 0  W - Ht Water/Steam         NaN        N - None        0.0         NaN
# 1  F - Forced Hot Air         NaN  C - Central AC        0.0         NaN
# 2      S - Space Heat         NaN        N - None        0.0         NaN
# 3  W - Ht Water/Steam         NaN        N - None        0.0         NaN
# 4  W - Ht Water/Steam         NaN        N - None        0.0         NaN
#
#   NUM_PARKING    PROP_VIEW CORNER_UNIT
# 0         3.0  A - Average         NaN
# 1         0.0  A - Average         NaN
# 2         0.0  A - Average         NaN
# 3         0.0  A - Average         NaN
# 4         0.0  A - Average         NaN
#
# [5 rows x 65 columns]

# %%
# Check for null
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182242 entries, 0 to 182241
# Data columns (total 65 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   PID                  182242 non-null  int64
#  1   CM_ID                93291 non-null   float64
#  2   GIS_ID               182242 non-null  int64
#  3   ST_NUM               172879 non-null  float64
#  4   ST_NAME              182242 non-null  object
#  5   UNIT_NUM             82613 non-null   object
#  6   CITY                 182239 non-null  object
#  7   ZIP_CODE             182239 non-null  float64
#  8   BLDG_SEQ             182242 non-null  int64
#  9   NUM_BLDGS            182242 non-null  int64
#  10  LUC                  182242 non-null  int64
#  11  LU                   182242 non-null  object
#  12  LU_DESC              182242 non-null  object
#  13  BLDG_TYPE            179626 non-null  object
#  14  OWN_OCC              182242 non-null  object
#  15  OWNER                182242 non-null  object
#  16  MAIL_ADDRESSEE       34412 non-null   object
#  17  MAIL_STREET_ADDRESS  182238 non-null  object
#  18  MAIL_CITY            182231 non-null  object
#  19  MAIL_STATE           181923 non-null  object
#  20  MAIL_ZIP_CODE        182181 non-null  object
#  21  RES_FLOOR            148450 non-null  float64
#  22  CD_FLOOR             71972 non-null   float64
#  23  RES_UNITS            10768 non-null   float64
#  24  COM_UNITS            10768 non-null   float64
#  25  RC_UNITS             10768 non-null   float64
#  26  LAND_SF              174240 non-null  object
#  27  GROSS_AREA           148394 non-null  float64
#  28  LIVING_AREA          148101 non-null  float64
#  29  LAND_VALUE           182242 non-null  object
#  30  BLDG_VALUE           182242 non-null  object
#  31  SFYI_VALUE           182242 non-null  int64
#  32  TOTAL_VALUE          182242 non-null  object
#  33   GROSS_TAX           182242 non-null  object
#  34  YR_BUILT             159456 non-null  float64
#  35  YR_REMODEL           86718 non-null   float64
#  36  STRUCTURE_CLASS      17406 non-null   object
#  37  ROOF_STRUCTURE       146017 non-null  object
#  38  ROOF_COVER           146023 non-null  object
#  39  INT_WALL             133493 non-null  object
#  40  EXT_FNISHED          159358 non-null  object
#  41  INT_COND             133496 non-null  object
#  42  EXT_COND             146084 non-null  object
#  43  OVERALL_COND         172655 non-null  object
#  44  BED_RMS              133477 non-null  float64
#  45  FULL_BTH             170598 non-null  float64
#  46  HLF_BTH              170733 non-null  float64
#  47  KITCHENS             170524 non-null  float64
#  48  TT_RMS               133413 non-null  float64
#  49  BDRM_COND            71742 non-null   object
#  50  BTHRM_STYLE1         132694 non-null  object
#  51  BTHRM_STYLE2         85165 non-null   object
#  52  BTHRM_STYLE3         36502 non-null   object
#  53  KITCHEN_TYPE         132687 non-null  object
#  54  KITCHEN_STYLE1       132693 non-null  object
#  55  KITCHEN_STYLE2       31248 non-null   object
#  56  KITCHEN_STYLE3       13745 non-null   object
#  57  HEAT_TYPE            134000 non-null  object
#  58  HEAT_SYSTEM          72229 non-null   object
#  59  AC_TYPE              133970 non-null  object
#  60  FIREPLACES           132708 non-null  float64
#  61  ORIENTATION          71974 non-null   object
#  62  NUM_PARKING          133619 non-null  float64
#  63  PROP_VIEW            135289 non-null  object
#  64  CORNER_UNIT          71971 non-null   object
# dtypes: float64(19), int64(6), object(40)
# memory usage: 90.4+ MB

# %%
# Get rid of columns that contain over 60% null values
columns_to_drop = ['CM_ID', 'UNIT_NUM','MAIL_ADDRESSEE','CD_FLOOR','RES_UNITS',
                   'COM_UNITS','RC_UNITS','STRUCTURE_CLASS','BDRM_COND',
                   'BTHRM_STYLE2','BTHRM_STYLE3','KITCHEN_STYLE2','KITCHEN_STYLE3',
                   'HEAT_SYSTEM','ORIENTATION','CORNER_UNIT']
df.drop(columns=columns_to_drop, inplace=True)

# %%
# Clean null values
clean_data= df.dropna(inplace=True)

# %%
# # Check for null values again
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 68853 entries, 1 to 182239
# Data columns (total 49 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   PID                  68853 non-null  int64
#  1   GIS_ID               68853 non-null  int64
#  2   ST_NUM               68853 non-null  float64
#  3   ST_NAME              68853 non-null  object
#  4   CITY                 68853 non-null  object
#  5   ZIP_CODE             68853 non-null  float64
#  6   BLDG_SEQ             68853 non-null  int64
#  7   NUM_BLDGS            68853 non-null  int64
#  8   LUC                  68853 non-null  int64
#  9   LU                   68853 non-null  object
#  10  LU_DESC              68853 non-null  object
#  11  BLDG_TYPE            68853 non-null  object
#  12  OWN_OCC              68853 non-null  object
#  13  OWNER                68853 non-null  object
#  14  MAIL_STREET_ADDRESS  68853 non-null  object
#  15  MAIL_CITY            68853 non-null  object
#  16  MAIL_STATE           68853 non-null  object
#  17  MAIL_ZIP_CODE        68853 non-null  object
#  18  RES_FLOOR            68853 non-null  float64
#  19  LAND_SF              68853 non-null  object
#  20  GROSS_AREA           68853 non-null  float64
#  21  LIVING_AREA          68853 non-null  float64
#  22  LAND_VALUE           68853 non-null  object
#  23  BLDG_VALUE           68853 non-null  object
#  24  SFYI_VALUE           68853 non-null  int64
#  25  TOTAL_VALUE          68853 non-null  object
#  26   GROSS_TAX           68853 non-null  object
#  27  YR_BUILT             68853 non-null  float64
#  28  YR_REMODEL           68853 non-null  float64
#  29  ROOF_STRUCTURE       68853 non-null  object
#  30  ROOF_COVER           68853 non-null  object
#  31  INT_WALL             68853 non-null  object
#  32  EXT_FNISHED          68853 non-null  object
#  33  INT_COND             68853 non-null  object
#  34  EXT_COND             68853 non-null  object
#  35  OVERALL_COND         68853 non-null  object
#  36  BED_RMS              68853 non-null  float64
#  37  FULL_BTH             68853 non-null  float64
#  38  HLF_BTH              68853 non-null  float64
#  39  KITCHENS             68853 non-null  float64
#  40  TT_RMS               68853 non-null  float64
#  41  BTHRM_STYLE1         68853 non-null  object
#  42  KITCHEN_TYPE         68853 non-null  object
#  43  KITCHEN_STYLE1       68853 non-null  object
#  44  HEAT_TYPE            68853 non-null  object
#  45  AC_TYPE              68853 non-null  object
#  46  FIREPLACES           68853 non-null  float64
#  47  NUM_PARKING          68853 non-null  float64
#  48  PROP_VIEW            68853 non-null  object
# dtypes: float64(14), int64(6), object(29)
# memory usage: 26.3+ MB

# %%
df.head()
# Out:
#          PID     GIS_ID  ST_NUM       ST_NAME         CITY  ZIP_CODE  \
# 1  100002000  100002000   197.0  Lexington ST  EAST BOSTON    2128.0
# 2  100003000  100003000   199.0  Lexington ST  EAST BOSTON    2128.0
# 3  100004000  100004000   201.0  Lexington ST  EAST BOSTON    2128.0
# 4  100005000  100005000   203.0  Lexington ST  EAST BOSTON    2128.0
# 5  100006000  100006000   205.0  Lexington ST  EAST BOSTON    2128.0
#
#    BLDG_SEQ  NUM_BLDGS  LUC  LU  ... KITCHENS TT_RMS       BTHRM_STYLE1  \
# 1         1          1  105  R3  ...      3.0    9.0         M - Modern
# 2         1          1  105  R3  ...      3.0   13.0         M - Modern
# 3         1          1  105  R3  ...      3.0   11.0    S - Semi-Modern
# 4         1          1  104  R2  ...      2.0   13.0  N - No Remodeling
# 5         1          1  105  R3  ...      3.0   20.0         M - Modern
#
#                   KITCHEN_TYPE     KITCHEN_STYLE1           HEAT_TYPE  \
# 1  3F - 3 Full Eat In Kitchens         M - Modern  F - Forced Hot Air
# 2  3F - 3 Full Eat In Kitchens    S - Semi-Modern      S - Space Heat
# 3  3F - 3 Full Eat In Kitchens    S - Semi-Modern  W - Ht Water/Steam
# 4  2F - 2 Full Eat In Kitchens  N - No Remodeling  W - Ht Water/Steam
# 5  3F - 3 Full Eat In Kitchens         M - Modern        E - Electric
#
#           AC_TYPE FIREPLACES  NUM_PARKING    PROP_VIEW
# 1  C - Central AC        0.0          0.0  A - Average
# 2        N - None        0.0          0.0  A - Average
# 3        N - None        0.0          0.0  A - Average
# 4        N - None        0.0          0.0  A - Average
# 5        N - None        0.0          0.0  A - Average
#
# [5 rows x 49 columns]

# %%
csv_bytes = df.to_csv(index=False).encode()
blob_name = "clean_data_no_nulls.csv"

# %%
# Upload the CSV bytes to Azure
blob_client = container_client.get_blob_client(blob_name)
blob_client.upload_blob(csv_bytes, overwrite=True)
# Out:
# {'etag': '"0x8DC6574014E686A"',
#  'last_modified': datetime.datetime(2024, 4, 25, 22, 6, 49, tzinfo=datetime.timezone.utc),
#  'content_md5': bytearray(b'5:}`Ca/\x8d^v7\xf3\xaaj\x8f\x81'),
#  'client_request_id': '1c7e6264-0350-11ef-a982-0242ac1c000c',
#  'request_id': '1fed5bf3-f01e-0067-175c-9752f1000000',
#  'version': '2023-11-03',
#  'version_id': None,
#  'date': datetime.datetime(2024, 4, 25, 22, 6, 48, tzinfo=datetime.timezone.utc),
#  'request_server_encrypted': True,
#  'encryption_key_sha256': None,
#  'encryption_scope': None}
